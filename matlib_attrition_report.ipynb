# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
one_image=np.zeros((20,20))
one_image[:,11]=255
one_image[0,8:11]=255
plt.imshow(one_image)

# %%
img_array=plt.imread(r"E:\datascience\NUMPY\pic1.jpg")
img_array.shape
img_array[:,:,0].shape
plt.imshow(img_array[:,:,0])

# %%
img_array1=cv2.imread(r'E:\datascience\NUMPY\pic1.jpg')

img_array1.shape # height,width, colour image
resized=cv2.resize(img_array1,(800,600)) # name of image,width,height
img_array1[2500:3000,1000:1500]
cv2.imshow("feather",resized)
cv2.waitKey(2500) # 0 = infinite time, 1000 = 1 sec
cv2.destroyAllWindows()

# %%
labels=["Middle aged","Young aged","Adult"]
sizes=[1129,385,162]
colours=["skyblue","Darkblue","gray"]
explode=(0,0,0)
plt.figure(figsize=(3,3))  # Optional: Set the figure size

plt.pie(sizes, explode=explode, labels=labels, colors=colours,autopct='%1.1f%%')
        # autopct='%1.1f%%', shadow=True, startangle=140)
plt.axis('equal') 
plt.show()

# %%
categories=["Young aged","Middle aged","Adult"]
values=[101,88,10]
colours=["skyblue","darkblue",'grey']
plt.figure(figsize=(4,4)) 
plt.bar(categories,values)
plt.xlabel("Age")
plt.ylabel("No of employees")
plt.show()

# %%
x = [1, 2, 3, 4, 5]
y = [1, 3, 2, 5, 4]
plt.fill_between(x, y, color="skyblue", alpha=0.4)
plt.plot(x, y, color="Slateblue", alpha=0.6)
plt.title('Area Chart')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.show()

# %%
x1 = [1, 2, 3, 4, 5]
y1 = [2, 3, 5, 7, 11]

x2=[]
plt.plot(x,y)
plt.show()

# %%
labels=["Maternity","Cardiology","Neurology"]
values=[98,74,27]
colours=["Skyblue",'darkblue',"grey"]
plt.figure(figsize=(3,3))
plt.pie(values,labels=labels,colors=colours,autopct='%1.1f%%')
plt.show()
